# %%
run eigen.py

# %%
EigenFace()

# %% [markdown]
# ### Criando um objeto para o metódo EigenFaces.

# %%
eigen_face = EigenFace()

# %% [markdown]
# ##Tirando o PCA das Imagens

# %%
pca = eigen_face.get_pca()

# %% [markdown]
# ### Mostrando as imagens utilizadas.

# %%
eigen_face.plot_image_dictionary()
plt.show()

# %% [markdown]
# ### Mostrando as EigenFaces Criadas.

# %%
eigen_face.plot_eigen_vectors()
plt.show()

# %% [markdown]
# ### Mostrando a primeira EigenFace.

# %%
eigen_face.plot_eigen_vector(0)
plt.show()

# %% [markdown]
# #### Primeira Eigenface.

# %%
eigen_face.plot_mean_vector()
plt.show()

# %% [markdown]
# #### Plot dos Eigenvalues até 10.

# %%
eigen_face.plot_eigen_value_distribution(range(0,10))
plt.show()

# %% [markdown]
# #### Pegando o minimos de eigenvectors que explica 95% da variancia.

# %%
eigen_face.get_number_of_components_to_preserve_variance()
# Out:
# 3
